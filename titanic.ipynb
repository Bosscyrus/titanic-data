# %%
import numpy as np
import pandas as pd


df=pd.read_csv('train.csv')

# %%
df.shape
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(18, 6))

print("Those who Survived")
df.Survived.value_counts().plot(kind="bar", alpha=0.5, )
#normalize to give ur values in percentages


plt.show
# Out:
# Those who Survived
# <function matplotlib.pyplot.show>

# %%
print("Survived relating to age")
plt.scatter(df.Survived, df.Age, alpha=0.1)

plt.show

#to shhow who died more the old or the young
# Out:
# Survived relating to age
# <function matplotlib.pyplot.show>

# %%
# lets check the class that survived more
print("CLASS")
df.Pclass.value_counts().plot(kind="bar", alpha=0.5, )
#normalize to give ur values in percentages


plt.show
# Out:
# CLASS
# <function matplotlib.pyplot.show>

# %%
 df.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#lets add new columns to the datasets
df["Hypothesis"]=0
# loc is used to pass conditions
df.loc[df.Sex=="female", "Hypothesis"]=1

#lets produce another column for result
df["Result"]=0
df.loc[df.Survived ==df["Hypothesis"], "Result"]=1

print(df["Result"].value_counts(normalize = True))
# Out:
# 1    0.786756
# 0    0.213244
# Name: Result, dtype: float64

# %%
#import pandas as pd
df=pd.read_csv('train.csv')
include = ['Age', 'Sex', 'Embarked', 'Survived']
df_ = df[include]  # only using 4 variables

# %%
categoricals = []
for col, col_type in df_.dtypes.iteritems():
     if col_type == 'O':
          categoricals.append(col)
     else:
          df_[col].fillna(0, inplace=True)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\generic.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_ohe = pd.get_dummies(df, columns=categoricals, dummy_na=True)

# %%
# using a random forest classifier (can be any classifier)
from numpy.core.umath_tests import inner1d
from sklearn.preprocessing import OneHotEncoder as ohe
from sklearn.ensemble import RandomForestClassifier as rf
dependent_variable = 'Survived'
independent_variable = 'Pclass'
x = df_ohe[df_ohe.columns.difference([dependent_variable])]
#y = df_ohe[df_ohe.columns([independent_variable])]
clf = rf()
clf.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-244077b75c30> in <module>()
#       8 #y = df_ohe[df_ohe.columns([independent_variable])]
#       9 clf = rf()
# ---> 10 clf.fit(x, y)
#
# NameError: name 'y' is not defined

# %%
from sklearn.externals import joblib
joblib.dump(clf, 'model.pkl')

# %%
model_columns = list(x.columns)
joblib.dumps(model_columns, 'model_columns.pkl')

# %%
@app.route('/predict', methods=['POST'])
def predict():
     json_ = request.json
     query_df = pd.DataFrame(json_)
     query = pd.get_dummies(query_df)
     for col in model_columns:
          if col not in query.columns:
               query[col] = 0
     prediction = clf.predict(query)
     return jsonify({'prediction': list(prediction)})
if __name__ == '__main__':
     clf = joblib.load('model.pkl')
     model_columns = joblib.load('model_columns.pkl')
     app.run(port=8080)

# %%
           
           
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(X_train_ordinal)
dependent_variable = 'Survived'
X_train_one_hot = enc.transform[enc.transform.difference([dependent_variable])]
X_test_one_hot = enc.transform(X_test_ordinal)
l.fit(X_train_one_hot,y_train)
y_pred = l.predict_proba(X_test_one_hot)

r.fit(X_train_one_hot,y_train)
y_pred = r.predict_proba(X_test_one_hot)






           
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d31424737af0> in <module>()
#       3 from sklearn.preprocessing import OneHotEncoder
#       4 enc = OneHotEncoder(handle_unknown='ignore')
# ----> 5 enc.fit(X_train_ordinal)
#       6 X_train_one_hot = enc.transform(X_train_ordinal)
#       7 X_test_one_hot = enc.transform(X_test_ordinal)
#
# NameError: name 'X_train_ordinal' is not defined
