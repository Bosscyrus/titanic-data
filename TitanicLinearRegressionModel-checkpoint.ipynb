# %%
#data analysis libraries 
import numpy as np
import pandas as pd

#visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#import train and test CSV files
train = pd.read_csv("train_b.csv")
test = pd.read_csv("test_titanic.csv")

#take a look at the training data
train.describe(include="all")
# Out:
#         traveller_ID  ticket_class                  name   sex         age  \
# count     916.000000    916.000000                   916   916  729.000000
# unique           NaN           NaN                   915     2         NaN
# top              NaN           NaN  Connolly, Miss. Kate  male         NaN
# freq             NaN           NaN                     2   592         NaN
# mean      656.248908      2.305677                   NaN   NaN   29.102309
# std       381.176191      0.841811                   NaN   NaN   13.866954
# min         0.000000      1.000000                   NaN   NaN    0.166700
# 25%       328.250000      2.000000                   NaN   NaN   21.000000
# 50%       670.000000      3.000000                   NaN   NaN   28.000000
# 75%       974.250000      3.000000                   NaN   NaN   37.000000
# max      1308.000000      3.000000                   NaN   NaN   80.000000
#
#         Siblings_spouses     Parchil   TickNum        fare            cabin  \
# count         916.000000  916.000000       916  915.000000              204
# unique               NaN         NaN       694         NaN              146
# top                  NaN         NaN  CA. 2343         NaN  B57 B59 B63 B66
# freq                 NaN         NaN         9         NaN                5
# mean            0.539301    0.386463       NaN   33.709221              NaN
# std             1.082188    0.893933       NaN   52.840656              NaN
# min             0.000000    0.000000       NaN    0.000000              NaN
# 25%             0.000000    0.000000       NaN    7.925000              NaN
# 50%             0.000000    0.000000       NaN   14.500000              NaN
# 75%             1.000000    0.000000       NaN   31.275000              NaN
# max             8.000000    9.000000       NaN  512.329200              NaN
#
#        embarked MedBoat    Survived
# count       915     327  916.000000
# unique        3      24         NaN
# top           S      13         NaN
# freq        638      30         NaN
# mean        NaN     NaN    0.361354
# std         NaN     NaN    0.480655
# min         NaN     NaN    0.000000
# 25%         NaN     NaN    0.000000
# 50%         NaN     NaN    0.000000
# 75%         NaN     NaN    1.000000
# max         NaN     NaN    1.000000

# %%
#get a list of the features within the dataset
print(train.columns)
# Out:
# Index(['traveller_ID', 'ticket_class', 'name', 'sex', 'age',
#        'Siblings_spouses', 'Parchil', 'TickNum', 'fare', 'cabin', 'embarked',
#        'MedBoat', 'Survived'],
#       dtype='object')

# %%
#see a sample of the dataset to get an idea of the variables
train.sample(5)
# Out:
#      traveller_ID  ticket_class                        name     sex   age  \
# 114           874             3          Hyman, Mr. Abraham    male   NaN
# 787           742             3       Dahl, Mr. Karl Edwart    male  45.0
# 552           669             3  Beavan, Mr. William Thomas    male  19.0
# 675           469             2         Keane, Miss. Nora A  female   NaN
# 537          1248             3          Tikkanen, Mr. Juho    male  32.0
#
#      Siblings_spouses  Parchil            TickNum     fare cabin embarked  \
# 114                 0        0               3470   7.8875   NaN        S
# 787                 0        0               7598   8.0500   NaN        S
# 552                 0        0             323951   8.0500   NaN        S
# 675                 0        0             226593  12.3500  E101        Q
# 537                 0        0  STON/O 2. 3101293   7.9250   NaN        S
#
#     MedBoat  Survived
# 114       C         1
# 787      15         1
# 552     NaN         0
# 675      10         1
# 537     NaN         0

# %%
#see a summary of the training dataset
train.describe(include = "all")
# Out:
#         traveller_ID  ticket_class                  name   sex         age  \
# count     916.000000    916.000000                   916   916  729.000000
# unique           NaN           NaN                   915     2         NaN
# top              NaN           NaN  Connolly, Miss. Kate  male         NaN
# freq             NaN           NaN                     2   592         NaN
# mean      656.248908      2.305677                   NaN   NaN   29.102309
# std       381.176191      0.841811                   NaN   NaN   13.866954
# min         0.000000      1.000000                   NaN   NaN    0.166700
# 25%       328.250000      2.000000                   NaN   NaN   21.000000
# 50%       670.000000      3.000000                   NaN   NaN   28.000000
# 75%       974.250000      3.000000                   NaN   NaN   37.000000
# max      1308.000000      3.000000                   NaN   NaN   80.000000
#
#         Siblings_spouses     Parchil   TickNum        fare            cabin  \
# count         916.000000  916.000000       916  915.000000              204
# unique               NaN         NaN       694         NaN              146
# top                  NaN         NaN  CA. 2343         NaN  B57 B59 B63 B66
# freq                 NaN         NaN         9         NaN                5
# mean            0.539301    0.386463       NaN   33.709221              NaN
# std             1.082188    0.893933       NaN   52.840656              NaN
# min             0.000000    0.000000       NaN    0.000000              NaN
# 25%             0.000000    0.000000       NaN    7.925000              NaN
# 50%             0.000000    0.000000       NaN   14.500000              NaN
# 75%             1.000000    0.000000       NaN   31.275000              NaN
# max             8.000000    9.000000       NaN  512.329200              NaN
#
#        embarked MedBoat    Survived
# count       915     327  916.000000
# unique        3      24         NaN
# top           S      13         NaN
# freq        638      30         NaN
# mean        NaN     NaN    0.361354
# std         NaN     NaN    0.480655
# min         NaN     NaN    0.000000
# 25%         NaN     NaN    0.000000
# 50%         NaN     NaN    0.000000
# 75%         NaN     NaN    1.000000
# max         NaN     NaN    1.000000

# %%
#check for any other unusable values
print(pd.isnull(train).sum())
# Out:
# traveller_ID          0
# ticket_class          0
# name                  0
# sex                   0
# age                 187
# Siblings_spouses      0
# Parchil               0
# TickNum               0
# fare                  1
# cabin               712
# embarked              1
# MedBoat             589
# Survived              0
# dtype: int64

# %%
#draw a bar plot of survival by sex
sns.barplot(x="sex", y="Survived", data=train)

#print percentages of females vs. males that survive
print("Percentage of females who survived:", train["Survived"][train["sex"] == 'female'].value_counts(normalize = True)[1]*100)

print("Percentage of males who survived:", train["Survived"][train["sex"] == 'male'].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of females who survived: 69.44444444444444
# Percentage of males who survived: 17.905405405405407

# %%
#draw a bar plot of survival by Pclass
sns.barplot(x="ticket_class", y="Survived", data=train)

#print percentage of people by Pclass that survived
print("Percentage of Pclass = 1 who survived:", train["Survived"][train["ticket_class"] == 1].value_counts(normalize = True)[1]*100)

print("Percentage of Pclass = 2 who survived:", train["Survived"][train["ticket_class"] == 2].value_counts(normalize = True)[1]*100)

print("Percentage of Pclass = 3 who survived:", train["Survived"][train["ticket_class"] == 3].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of Pclass = 1 who survived: 60.792951541850215
# Percentage of Pclass = 2 who survived: 39.010989010989015
# Percentage of Pclass = 3 who survived: 24.06311637080868

# %%
#draw a bar plot for SibSp vs. survival
sns.barplot(x="Siblings_spouses", y="Survived", data=train)

#I won't be printing individual percent values for all of these.
print("Percentage of SibSp = 0 who survived:", train["Survived"][train["Siblings_spouses"] == 0].value_counts(normalize = True)[1]*100)

print("Percentage of SibSp = 1 who survived:", train["Survived"][train["Siblings_spouses"] == 1].value_counts(normalize = True)[1]*100)

print("Percentage of SibSp = 2 who survived:", train["Survived"][train["Siblings_spouses"] == 2].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of SibSp = 0 who survived: 32.06611570247934
# Percentage of SibSp = 1 who survived: 48.497854077253216
# Percentage of SibSp = 2 who survived: 48.484848484848484

# %%
#draw a bar plot for Parch vs. survival
sns.barplot(x="Parchil", y="Survived", data=train)
plt.show()

# %%
#draw a bar plot for Parch vs. survival
sns.barplot(x="MedBoat", y="Survived", data=train)
plt.show()

# %%
#sort the ages into logical categories
train["age"] = train["age"].fillna(-0.5)
test["age"] = test["age"].fillna(-0.5)
bins = [-1, 0, 5, 12, 18, 24, 35, 60, np.inf]
labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
train['AgeGroup'] = pd.cut(train["age"], bins, labels = labels)
test['AgeGroup'] = pd.cut(test["age"], bins, labels = labels)

#draw a bar plot of Age vs. survival
sns.barplot(x="AgeGroup", y="Survived", data=train)
plt.show()

# %%
train["CabinBool"] = (train["cabin"].notnull().astype('int'))
test["CabinBool"] = (test["cabin"].notnull().astype('int'))

#calculate percentages of CabinBool vs. survived
print("Percentage of CabinBool = 1 who survived:", train["Survived"][train["CabinBool"] == 1].value_counts(normalize = True)[1]*100)

print("Percentage of CabinBool = 0 who survived:", train["Survived"][train["CabinBool"] == 0].value_counts(normalize = True)[1]*100)
#draw a bar plot of CabinBool vs. survival
sns.barplot(x="CabinBool", y="Survived", data=train)
plt.show()
# Out:
# Percentage of CabinBool = 1 who survived: 64.70588235294117
# Percentage of CabinBool = 0 who survived: 27.94943820224719

# %%
# lets clean the data
test.describe(include="all")
# Out:
#         traveller_ID  ticket_class                   name   sex         age  \
# count     393.000000    393.000000                    393   393  393.000000
# unique           NaN           NaN                    393     2         NaN
# top              NaN           NaN  Betros, Master. Seman  male         NaN
# freq             NaN           NaN                      1   251         NaN
# mean      648.758270      2.269720                    NaN   NaN   25.450594
# std       370.986997      0.829017                    NaN   NaN   18.837460
# min        10.000000      1.000000                    NaN   NaN   -0.500000
# 25%       327.000000      2.000000                    NaN   NaN    8.000000
# 50%       618.000000      3.000000                    NaN   NaN   26.000000
# 75%       986.000000      3.000000                    NaN   NaN   38.000000
# max      1301.000000      3.000000                    NaN   NaN   74.000000
#
#         Siblings_spouses     Parchil   TickNum        fare cabin embarked  \
# count         393.000000  393.000000       393  393.000000    91      392
# unique               NaN         NaN       345         NaN    76        3
# top                  NaN         NaN  PC 17582         NaN   E34        S
# freq                 NaN         NaN         3         NaN     2      276
# mean            0.404580    0.381679       NaN   32.332188   NaN      NaN
# std             0.934967    0.796594       NaN   49.199401   NaN      NaN
# min             0.000000    0.000000       NaN    0.000000   NaN      NaN
# 25%             0.000000    0.000000       NaN    7.895800   NaN      NaN
# 50%             0.000000    0.000000       NaN   13.000000   NaN      NaN
# 75%             1.000000    0.000000       NaN   31.275000   NaN      NaN
# max             8.000000    6.000000       NaN  512.329200   NaN      NaN
#
#        MedBoat AgeGroup   CabinBool
# count      159      393  393.000000
# unique      23        8         NaN
# top         14    Adult         NaN
# freq        16      104         NaN
# mean       NaN      NaN    0.231552
# std        NaN      NaN    0.422362
# min        NaN      NaN    0.000000
# 25%        NaN      NaN    0.000000
# 50%        NaN      NaN    0.000000
# 75%        NaN      NaN    0.000000
# max        NaN      NaN    1.000000

# %%
#we'll start off by dropping the Cabin feature since not a lot more useful information can be extracted from it.
train = train.drop(['cabin'], axis = 1)
test = test.drop(['cabin'], axis = 1)

#we can also drop the Ticket feature since it's unlikely to yield any useful information
train = train.drop(['TickNum'], axis = 1)
test = test.drop(['TickNum'], axis = 1)

#now we need to fill in the missing values in the Embarked feature
print("Number of people embarking in Southampton (S):")
southampton = train[train["embarked"] == "S"].shape[0]
print(southampton)

print("Number of people embarking in Cherbourg (C):")
cherbourg = train[train["embarked"] == "C"].shape[0]
print(cherbourg)

print("Number of people embarking in Queenstown (Q):")
queenstown = train[train["embarked"] == "Q"].shape[0]
print(queenstown)
# Out:
# Number of people embarking in Southampton (S):
# 638
# Number of people embarking in Cherbourg (C):
# 187
# Number of people embarking in Queenstown (Q):
# 90

# %%
#replacing the missing values in the Embarked feature with S
train = train.fillna({"Embarked": "S"})
test = test.fillna({"Embarked": "S"})

# %%
#since a large number of missing values went for age
#create a combined group of both datasets
combine = [train, test]

#extract a title for each Name in the train and test datasets
for dataset in combine:
    dataset['Title'] = dataset.name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train['Title'], train['sex'])
# Out:
# sex       female  male
# Title
# Col            0     3
# Countess       1     0
# Don            0     1
# Dr             1     7
# Jonkheer       0     1
# Lady           1     0
# Major          0     1
# Master         0    41
# Miss         184     0
# Mlle           1     0
# Mme            1     0
# Mr             0   530
# Mrs          133     0
# Ms             2     0
# Rev            0     7
# Sir            0     1

# %%
#replace various titles with more common names
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Capt', 'Col',
    'Don', 'Dr', 'Major', 'Rev', 'Jonkheer', 'Dona'], 'Rare')
    
    dataset['Title'] = dataset['Title'].replace(['Countess', 'Lady', 'Sir'], 'Royal')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.487805
# 1    Miss  0.631016
# 2      Mr  0.150943
# 3     Mrs  0.776119
# 4    Rare  0.318182
# 5   Royal  1.000000

# %%
#map each of the title groups to a numerical value
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Royal": 5, "Rare": 6}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

train.head()
# Out:
#    traveller_ID  ticket_class  \
# 0          1214             3
# 1           677             3
# 2           534             2
# 3          1174             3
# 4           864             3
#
#                                                 name     sex   age  \
# 0                                Smiljanic, Mr. Mile    male  -0.5
# 1                          Bostandyeff, Mr. Guentcho    male  26.0
# 2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0
# 3                  Sage, Miss. Dorothy Edith "Dolly"  female  -0.5
# 4                     Henriksson, Miss. Jenny Lovisa  female  28.0
#
#    Siblings_spouses  Parchil     fare embarked MedBoat  Survived     AgeGroup  \
# 0                 0        0   8.6625        S     NaN         0      Unknown
# 1                 0        0   7.8958        S     NaN         0  Young Adult
# 2                 0        0  26.0000        S      11         1      Student
# 3                 8        2  69.5500        S     NaN         0      Unknown
# 4                 0        0   7.7750        S     NaN         0  Young Adult
#
#    CabinBool  Title
# 0          0      1
# 1          0      1
# 2          0      2
# 3          0      2
# 4          0      2

# %%
#map each Age value to a numerical value
age_mapping = {'Unknown': 0,'Baby': 1, 'Child': 2, 'Teenager': 3, 'Student': 4, 'Young Adult': 5, 'Adult': 6, 'Senior': 7}
train['AgeGroup'] = train['AgeGroup'].map(age_mapping)
test['AgeGroup'] = test['AgeGroup'].map(age_mapping)

train.head()

#dropping the Age feature for now, might change
train = train.drop(['age'], axis = 1)
test = test.drop(['age'], axis = 1)

#drop the name feature since it contains no more useful information.
train = train.drop(['name'], axis = 1)
test = test.drop(['name'], axis = 1)

#drop Fare values
train = train.drop(['fare'], axis = 1)
test = test.drop(['fare'], axis = 1)


train = train.drop(['MedBoat'], axis = 1)
test = test.drop(['MedBoat'], axis = 1)

# %%
#map each Sex value to a numerical value
sex_mapping = {"male": 0, "female": 1}
train['sex'] = train['sex'].map(sex_mapping)
test['sex'] = test['sex'].map(sex_mapping)

#map each Embarked value to a numerical value
embarked_mapping = {"S": 1, "C": 2, "Q": 3}
train['embarked'] = train['embarked'].map(embarked_mapping)
test['embarked'] = test['embarked'].map(embarked_mapping)


train.head()
# Out:
#    traveller_ID  ticket_class  sex  Siblings_spouses  Parchil  embarked  \
# 0          1214             3    0                 0        0       1.0
# 1           677             3    0                 0        0       1.0
# 2           534             2    1                 0        0       1.0
# 3          1174             3    1                 8        2       1.0
# 4           864             3    1                 0        0       1.0
#
#    Survived  AgeGroup  CabinBool  Title
# 0         0         0          0      1
# 1         0         5          0      1
# 2         1         4          0      2
# 3         0         0          0      2
# 4         0         5          0      2

# %%
#dropping the Age feature for now, might change
train = train.drop(['CabinBool'], axis = 1)
test = test.drop(['CabinBool'], axis = 1)
train = train.drop(['embarked'], axis = 1)
test = test.drop(['embarked'], axis = 1)

# %%
test.head()
# Out:
#    traveller_ID  ticket_class  sex  Siblings_spouses  Parchil  AgeGroup  Title
# 0          1148           3.0    0               0.0      0.0         5      1
# 1          1049           3.0    0               1.0      1.0         4      1
# 2           982           3.0    0               0.0      0.0         0      1
# 3           808           3.0    0               0.0      0.0         0      1
# 4          1195           3.0    0               0.0      0.0         0      1

# %%
train.head()
# Out:
#    traveller_ID  ticket_class  sex  Siblings_spouses  Parchil  Survived  \
# 0          1214             3    0                 0        0         0
# 1           677             3    0                 0        0         0
# 2           534             2    1                 0        0         1
# 3          1174             3    1                 8        2         0
# 4           864             3    1                 0        0         0
#
#    AgeGroup  Title
# 0         0      1
# 1         5      1
# 2         4      2
# 3         0      2
# 4         5      2

# %%
train.head()
# Out:
#    traveller_ID  ticket_class  sex  Siblings_spouses  Parchil  Survived  \
# 0          1214             3    0                 0        0         0
# 1           677             3    0                 0        0         0
# 2           534             2    1                 0        0         1
# 3          1174             3    1                 8        2         0
# 4           864             3    1                 0        0         0
#
#    AgeGroup  Title
# 0         0      1
# 1         5      1
# 2         4      2
# 3         0      2
# 4         5      2

# %%
# to cheeck if any of your column dont return a number
import numpy as np
np.all(np.isfinite(train))
# Out:
# True

# %%
# getting rid of infinite values
train.replace([np.inf, -np.inf], np.nan, inplace=True)
test.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
from sklearn.model_selection import train_test_split

predictors = train.drop(['traveller_ID','Survived'], axis=1)
target = train["Survived"]
x_train, x_val, y_train, y_val = train_test_split(predictors, target, test_size = 0.22, random_state = 0)

# %%
# KNN or k-Nearest Neighbors
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier 

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_val)
acc_knn = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_knn)
# Out:
# 77.23

# %%
# Support Vector Machines
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
y_pred = svc.predict(x_val)
acc_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_svc)
# Out:
# 79.7

# %%
# Perceptron
from sklearn.linear_model import Perceptron

perceptron = Perceptron()
perceptron.fit(x_train, y_train)
y_pred = perceptron.predict(x_val)
acc_perceptron = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_perceptron)
# Out:
# 73.27

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier

decisiontree = DecisionTreeClassifier()
decisiontree.fit(x_train, y_train)
y_pred = decisiontree.predict(x_val)
acc_decisiontree = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_decisiontree)
# Out:
# 75.74

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier()
randomforest.fit(x_train, y_train)
y_pred = randomforest.predict(x_val)
acc_randomforest = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_randomforest)
# Out:
# 79.21

# %%
# Stochastic Gradient Descent
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier()
sgd.fit(x_train, y_train)
y_pred = sgd.predict(x_val)
acc_sgd = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_sgd)
# Out:
# 77.23

# %%
# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

gbk = GradientBoostingClassifier()
gbk.fit(x_train, y_train)
y_pred = gbk.predict(x_val)
acc_gbk = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gbk)
# Out:
# 75.25

# %%
# Linear SVC
from sklearn.svm import LinearSVC

linear_svc = LinearSVC()
linear_svc.fit(x_train, y_train)
y_pred = linear_svc.predict(x_val)
acc_linear_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_linear_svc)
# Out:
# 77.72

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_val)
acc_logreg = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_logreg)
# Out:
# 77.72

# %%
# Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
y_pred = gaussian.predict(x_val)
acc_gaussian = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gaussian)
# Out:
# 76.73

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
# Instantiate our model
adaboost = AdaBoostClassifier()

# Fit our model to the training data
adaboost.fit(x_train, y_train)

# Predict on the test data
y_pred = adaboost.predict(x_val)

acc_gaussian = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gaussian)
# Out:
# 79.21

# %%
# Instantiate our model
bag = BaggingClassifier()

# Fit our model to the training data
bag.fit(x_train, y_train)

# Predict on the test data
y_pred = bag.predict(x_val)
acc_gaussian = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gaussian)
# Out:
# 75.25

# %%
# Instantiate our model
gb = GradientBoostingClassifier()
gb.fit(x_train, y_train)

y_pred = gb.predict(x_val)

acc_gaussian = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gaussian)
# Out:
# 75.25

# %%
# lets compare the different models

models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 'Linear SVC', 
              'Decision Tree', 'Stochastic Gradient Descent', 'Gradient Boosting Classifier'],
    'Score': [acc_svc, acc_knn, acc_logreg, 
              acc_randomforest, acc_gaussian, acc_perceptron,acc_linear_svc, acc_decisiontree,
              acc_sgd, acc_gbk]})
models.sort_values(by='Score', ascending=False)
# Out:
#                           Model  Score
# 0       Support Vector Machines  79.70
# 3                 Random Forest  79.21
# 2           Logistic Regression  77.72
# 6                    Linear SVC  77.72
# 1                           KNN  77.23
# 8   Stochastic Gradient Descent  77.23
# 4                   Naive Bayes  76.73
# 7                 Decision Tree  75.74
# 9  Gradient Boosting Classifier  75.25
# 5                    Perceptron  73.27

# %%
train
# Out:
#      traveller_ID  ticket_class  sex  Siblings_spouses  Parchil  Survived  \
# 0            1214             3    0                 0        0         0
# 1             677             3    0                 0        0         0
# 2             534             2    1                 0        0         1
# 3            1174             3    1                 8        2         0
# 4             864             3    1                 0        0         0
# 5             895             3    1                 1        1         1
# 6             813             3    0                 0        0         0
# 7             745             3    1                 0        0         1
# 8            1030             3    0                 0        0         0
# 9            1072             3    0                 0        0         0
# 10            425             2    0                 0        0         0
# 11            846             3    0                 0        0         0
# 12           1245             3    0                 0        0         0
# 13            321             1    0                 0        0         0
# 14            847             3    0                 0        0         0
# 15            989             3    0                 0        0         0
# 16            654             3    0                 0        0         0
# 17           1003             3    0                 2        0         1
# 18            433             2    0                 0        0         0
# 19             39             1    0                 0        0         0
# 20             30             1    0                 0        0         0
# 21            242             1    1                 0        0         1
# 22            796             3    0                 0        0         0
# 23            906             3    0                 0        0         0
# 24            136             1    0                 0        0         1
# 25            310             1    0                 1        1         0
# 26           1092             3    0                 0        0         0
# 27            852             3    1                 0        0         0
# 28            442             2    0                 2        0         0
# 29           1156             3    1                 1        1         0
# ..            ...           ...  ...               ...      ...       ...
# 886           510             2    0                 0        0         0
# 887          1082             3    0                 0        1         1
# 888           474             2    0                 0        0         0
# 889           856             3    1                 0        0         1
# 890           747             3    0                 0        2         0
# 891           252             1    0                 1        3         0
# 892            21             1    1                 1        1         1
# 893           459             2    0                 1        0         0
# 894          1184             3    0                 2        0         0
# 895           276             1    0                 1        0         0
# 896           955             3    1                 3        1         0
# 897          1215             3    0                 0        0         0
# 898           385             2    0                 1        1         1
# 899           805             3    0                 0        0         1
# 900           343             2    0                 0        0         1
# 901           769             3    0                 0        0         0
# 902           130             1    1                 0        1         1
# 903           871             3    0                 0        0         0
# 904          1123             3    1                 0        2         1
# 905            87             1    0                 0        0         1
# 906           330             2    0                 0        0         0
# 907          1238             3    0                 0        0         1
# 908           466             2    0                 1        0         0
# 909           121             1    1                 1        0         1
# 910          1044             3    1                 0        0         1
# 911          1095             3    1                 0        0         0
# 912          1130             3    1                 0        0         0
# 913          1294             3    0                 0        0         0
# 914           860             3    1                 0        0         1
# 915          1126             3    1                 0        0         0
#
#      AgeGroup  Title
# 0           0      1
# 1           5      1
# 2           4      2
# 3           0      2
# 4           5      2
# 5           1      2
# 6           0      1
# 7           5      2
# 8           0      1
# 9           0      1
# 10          6      1
# 11          4      1
# 12          0      1
# 13          7      1
# 14          4      1
# 15          0      1
# 16          4      1
# 17          0      1
# 18          5      1
# 19          6      1
# 20          6      1
# 21          5      2
# 22          6      1
# 23          5      1
# 24          6      6
# 25          6      1
# 26          4      1
# 27          0      2
# 28          4      1
# 29          1      2
# ..        ...    ...
# 886         3      1
# 887         2      4
# 888         5      1
# 889         0      2
# 890         1      4
# 891         7      1
# 892         6      3
# 893         6      1
# 894         0      1
# 895         6      1
# 896         0      2
# 897         0      1
# 898         2      4
# 899         0      1
# 900         5      1
# 901         4      1
# 902         4      2
# 903         0      1
# 904         0      3
# 905         5      1
# 906         6      1
# 907         5      1
# 908         5      1
# 909         0      3
# 910         0      2
# 911         0      2
# 912         3      2
# 913         5      1
# 914         5      2
# 915         5      2
#
# [916 rows x 8 columns]

# %%
#set ids as PassengerId and predict survival 
ids = test['traveller_ID']

predictions = randomforest.predict(test.drop('traveller_ID', axis=1))
                        
                          
# getting rid of infinite values
#test.replace([np.inf, -np.inf], np.nan, inplace=True)

#set the output as a dataframe and convert to csv file named submission.csv
output = pd.DataFrame({ 'traveller_ID' : ids, 'Survived': predictions })
output.to_csv('submsion.csv', index=False)
